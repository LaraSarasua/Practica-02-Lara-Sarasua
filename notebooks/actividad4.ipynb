# %%
import sys
sys.path.append('../')

# %%
from src.ejercicio04 import validar_email

# %%
email = input("Ingrese un correo electrónico para validar: ")
if validar_email(email):
    print("El email es válido.")
else:
    print("El email no es válido.")
