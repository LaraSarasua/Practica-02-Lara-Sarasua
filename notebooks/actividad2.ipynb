# %%
import sys
sys.path.append('../')

# %%
from src.ejercicio02 import calcular_duracion_total
from src.ejercicio02 import calcular_min_and_max

# %%
playlist = [
{"title": "Bohemian Rhapsody", "duration": "5:55"},
{"title": "Hotel California", "duration": "6:30"},
{"title": "Stairway to Heaven", "duration": "8:02"},
{"title": "Imagine", "duration": "3:07"},
{"title": "Smells Like Teen Spirit", "duration": "5:01"},
{"title": "Billie Jean", "duration": "4:54"},
{"title": "Hey Jude", "duration": "7:11"},
{"title": "Like a Rolling Stone", "duration": "6:13"},
]

m, s = calcular_duracion_total(playlist)
print(f"Duración total de la playlist: {m} minutos y {s} segundos")

min, max = calcular_min_and_max(playlist)
print(f"Cancion con duración mínima: {min} segundos")
print(f"Cancion con duración máxima: {max} segundos")
# Out:
# Duración total de la playlist: 46 minutos y 53 segundos
